# %%
#########################
# Pandas
#########################
import pandas
pandas.__version__
# Out:
# '2.1.0'

# %%
# Dataframes, series y índices
pokemon = ["Bulbasaur", "Squirtle", "Charizard",
           "Pikachu", "Onix", "Geodude", "Vulpix", "Starmie"]
types = ["Grass Poison", "Water", "Fire Flying", "Electric",
         "Rock Ground",  "Rock Ground", "Fire", "Water"]
master = ["Ash", "Ash", "Ash", "Ash", "Brock", "Brock", "Misty", "Misty"]
pokedex_number = [1, 4, 7, 25, 95, 74, 37, 121]

pandas.DataFrame({'pokemon': pokemon,
                  'type': types,
                  'master': master,
                  'number': pokedex_number})
# Out:
#      pokemon          type master  number
# 0  Bulbasaur  Grass Poison    Ash       1
# 1   Squirtle         Water    Ash       4
# 2  Charizard   Fire Flying    Ash       7
# 3    Pikachu      Electric    Ash      25
# 4       Onix   Rock Ground  Brock      95
# 5    Geodude   Rock Ground  Brock      74
# 6     Vulpix          Fire  Misty      37
# 7    Starmie         Water  Misty     121

# %%
df_pokemon = pandas.DataFrame({'pokemon': pokemon,
                  'type': types,
                  'master': master,
                  'number': pokedex_number})
df_pokemon
# Out:
#      pokemon          type master  number
# 0  Bulbasaur  Grass Poison    Ash       1
# 1   Squirtle         Water    Ash       4
# 2  Charizard   Fire Flying    Ash       7
# 3    Pikachu      Electric    Ash      25
# 4       Onix   Rock Ground  Brock      95
# 5    Geodude   Rock Ground  Brock      74
# 6     Vulpix          Fire  Misty      37
# 7    Starmie         Water  Misty     121

# %%
type(df_pokemon)
# Out:
# pandas.core.frame.DataFrame

# %%
df_pokemon.values
# Out:
# array([['Bulbasaur', 'Grass Poison', 'Ash', 1],
#        ['Squirtle', 'Water', 'Ash', 4],
#        ['Charizard', 'Fire Flying', 'Ash', 7],
#        ['Pikachu', 'Electric', 'Ash', 25],
#        ['Onix', 'Rock Ground', 'Brock', 95],
#        ['Geodude', 'Rock Ground', 'Brock', 74],
#        ['Vulpix', 'Fire', 'Misty', 37],
#        ['Starmie', 'Water', 'Misty', 121]], dtype=object)

# %%
type(df_pokemon.values)
# Out:
# numpy.ndarray

# %%
# Out:
#      pokemon          type master  number
# 0  Bulbasaur  Grass Poison    Ash       1
# 1   Squirtle         Water    Ash       4
# 2  Charizard   Fire Flying    Ash       7
# 3    Pikachu      Electric    Ash      25
# 4       Onix   Rock Ground  Brock      95
# 5    Geodude   Rock Ground  Brock      74
# 6     Vulpix          Fire  Misty      37
# 7    Starmie         Water  Misty     121

# %%
# Series
df_pokemon['pokemon']
# Out:
# pandas.core.series.Series

# %%
type(df_pokemon['pokemon'])
# Out:
# pandas.core.series.Series

# %%
df_pokemon['pokemon'].values
# Out:
# array(['Bulbasaur', 'Squirtle', 'Charizard', 'Pikachu', 'Onix', 'Geodude',
#        'Vulpix', 'Starmie'], dtype=object)

# %%
type(df_pokemon['pokemon'].values)
# Out:
# numpy.ndarray

# %%
df_pokemon['pokemon'].name
# Out:
# 'pokemon'

# %%
# Las series son arreglos de numpy con un nombre, por lo que se le puede aplicar los métodos conocidos de numpy para obtener resultados
df_pokemon['number'].max()
# Out:
# 121

# %%
# Columnas e Índices
df_pokemon
# Out:
#      pokemon          type master  number
# 0  Bulbasaur  Grass Poison    Ash       1
# 1   Squirtle         Water    Ash       4
# 2  Charizard   Fire Flying    Ash       7
# 3    Pikachu      Electric    Ash      25
# 4       Onix   Rock Ground  Brock      95
# 5    Geodude   Rock Ground  Brock      74
# 6     Vulpix          Fire  Misty      37
# 7    Starmie         Water  Misty     121

# %%
df_pokemon.columns
# Out:
# Index(['pokemon', 'type', 'master', 'number'], dtype='object')

# %%
type(df_pokemon.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df_pokemon.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
type(df_pokemon.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df_pokemon.loc[3, 'type']
# Out:
# 'Electric'

# %%
# Agregar, reordenar y eliminar columnas
df_pokemon
# Out:
#      pokemon          type master  number
# 0  Bulbasaur  Grass Poison    Ash       1
# 1   Squirtle         Water    Ash       4
# 2  Charizard   Fire Flying    Ash       7
# 3    Pikachu      Electric    Ash      25
# 4       Onix   Rock Ground  Brock      95
# 5    Geodude   Rock Ground  Brock      74
# 6     Vulpix          Fire  Misty      37
# 7    Starmie         Water  Misty     121

# %%
evolved = ["No", "No", "Yes", "No", "No", "No", "No", "Yes"]
df_pokemon['evolved'] = evolved
df_pokemon
# Out:
#      pokemon          type master  number evolved
# 0  Bulbasaur  Grass Poison    Ash       1      No
# 1   Squirtle         Water    Ash       4      No
# 2  Charizard   Fire Flying    Ash       7     Yes
# 3    Pikachu      Electric    Ash      25      No
# 4       Onix   Rock Ground  Brock      95      No
# 5    Geodude   Rock Ground  Brock      74      No
# 6     Vulpix          Fire  Misty      37      No
# 7    Starmie         Water  Misty     121     Yes

# %%
df_pokemon['region'] = 'Kanto'
df_pokemon
# Out:
#      pokemon          type master  number evolved region
# 0  Bulbasaur  Grass Poison    Ash       1      No  Kanto
# 1   Squirtle         Water    Ash       4      No  Kanto
# 2  Charizard   Fire Flying    Ash       7     Yes  Kanto
# 3    Pikachu      Electric    Ash      25      No  Kanto
# 4       Onix   Rock Ground  Brock      95      No  Kanto
# 5    Geodude   Rock Ground  Brock      74      No  Kanto
# 6     Vulpix          Fire  Misty      37      No  Kanto
# 7    Starmie         Water  Misty     121     Yes  Kanto

# %%
df_pokemon.columns
# Out:
# Index(['pokemon', 'type', 'master', 'number', 'evolved', 'region'], dtype='object')

# %%
df_pokemon = df_pokemon[['region', 'pokemon', 'type', 'master', 'number', 'evolved']]
df_pokemon
# Out:
#   region    pokemon          type master  number evolved
# 0  Kanto  Bulbasaur  Grass Poison    Ash       1      No
# 1  Kanto   Squirtle         Water    Ash       4      No
# 2  Kanto  Charizard   Fire Flying    Ash       7     Yes
# 3  Kanto    Pikachu      Electric    Ash      25      No
# 4  Kanto       Onix   Rock Ground  Brock      95      No
# 5  Kanto    Geodude   Rock Ground  Brock      74      No
# 6  Kanto     Vulpix          Fire  Misty      37      No
# 7  Kanto    Starmie         Water  Misty     121     Yes

# %%
df_pokemon[['pokemon', 'type']]
# Out:
#      pokemon          type
# 0  Bulbasaur  Grass Poison
# 1   Squirtle         Water
# 2  Charizard   Fire Flying
# 3    Pikachu      Electric
# 4       Onix   Rock Ground
# 5    Geodude   Rock Ground
# 6     Vulpix          Fire
# 7    Starmie         Water

# %%
# df_pokemon[['pokemon', 'tipo']]
df_pokemon.get(['pokemon', 'type'])
# Out:
#      pokemon          type
# 0  Bulbasaur  Grass Poison
# 4       Onix   Rock Ground
# 5    Geodude   Rock Ground
# 6     Vulpix          Fire
# 7    Starmie         Water
# 8     Togepi        Normal

# %%
df_pokemon.get(['pokemon', 'tipo'])
df_pokemon
# Out:
#   region    pokemon          type master number evolved
# 0  Kanto  Bulbasaur  Grass Poison    Ash      1      No
# 4  Kanto       Onix   Rock Ground  Brock     95      No
# 5  Kanto    Geodude   Rock Ground  Brock     74      No
# 6  Kanto     Vulpix          Fire  Misty     37      No
# 7  Kanto    Starmie         Water  Misty    121     Yes
# 8  Johto     Togepi        Normal  Misty             No

# %%
df_pokemon.drop('region', axis = 1)
# Out:
#      pokemon          type master  number evolved
# 0  Bulbasaur  Grass Poison    Ash       1      No
# 1   Squirtle         Water    Ash       4      No
# 2  Charizard   Fire Flying    Ash       7     Yes
# 3    Pikachu      Electric    Ash      25      No
# 4       Onix   Rock Ground  Brock      95      No
# 5    Geodude   Rock Ground  Brock      74      No
# 6     Vulpix          Fire  Misty      37      No
# 7    Starmie         Water  Misty     121     Yes

# %%
# Agregar, eliminar filas
nueva_fila = ["Johto", "Togepi", "Normal", "Misty", "", "No"]
df_pokemon.loc[8] = nueva_fila

# %%
df_pokemon
# Out:
#   region    pokemon          type master number evolved
# 0  Kanto  Bulbasaur  Grass Poison    Ash      1      No
# 3  Kanto    Pikachu      Electric    Ash     25      No
# 4  Kanto       Onix   Rock Ground  Brock     95      No
# 5  Kanto    Geodude   Rock Ground  Brock     74      No
# 6  Kanto     Vulpix          Fire  Misty     37      No
# 7  Kanto    Starmie         Water  Misty    121     Yes
# 8  Johto     Togepi        Normal  Misty             No

# %%
df_pokemon = df_pokemon.drop(3)
df_pokemon
# Out:
#   region    pokemon          type master number evolved
# 0  Kanto  Bulbasaur  Grass Poison    Ash      1      No
# 4  Kanto       Onix   Rock Ground  Brock     95      No
# 5  Kanto    Geodude   Rock Ground  Brock     74      No
# 6  Kanto     Vulpix          Fire  Misty     37      No
# 7  Kanto    Starmie         Water  Misty    121     Yes
# 8  Johto     Togepi        Normal  Misty             No

# %%
df_pokemon.loc[8, 'number'] = 175
df_pokemon
# Out:
#   region    pokemon          type master number evolved
# 0  Kanto  Bulbasaur  Grass Poison    Ash      1      No
# 4  Kanto       Onix   Rock Ground  Brock     95      No
# 5  Kanto    Geodude   Rock Ground  Brock     74      No
# 6  Kanto     Vulpix          Fire  Misty     37      No
# 7  Kanto    Starmie         Water  Misty    121     Yes
# 8  Johto     Togepi        Normal  Misty    175      No

# %%
# Lectura de fuentes de datos
import pandas
import os

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# os.listdir('C:\Users\ivanh\OneDrive\Downloads\files\world_cups.csv')
# Out:
#   Cell In[65], line 3
#     os.listdir('C:\Users\ivanh\OneDrive\Downloads\files\world_cups.csv')
#                                                                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df_pokedex = pandas.read_csv('C:\\Users\\ivanh\\Downloads\\files\\pokedex.csv')
df_pokedex
# Out:
#      pokedex_number        name   hp  attack  defense  sp_attack  sp_defense  \
# 0                 1   Bulbasaur   45      49       49         65          65
# 1                 2     Ivysaur   60      62       63         80          80
# 2                 3    Venusaur   80     100      123        122         120
# 3                 4  Charmander   39      52       43         60          50
# 4                 5  Charmeleon   58      64       58         80          65
# ..              ...         ...  ...     ...      ...        ...         ...
# 796             797  Celesteela   97     101      103        107         101
# 797             798     Kartana   59     181      131         59          31
# 798             799    Guzzlord  223     101       53         97          53
# 799             800    Necrozma   97     107      101        127          89
# 800             801    Magearna   80      95      115        130         115
#
# ...

# %%
df_mundiales = pandas.read_excel(
    'C:\\Users\\ivanh\\Downloads\\files\\world_cups.xlsx', sheet_name='players')
df_mundiales
# Out:
#        RoundID    MatchID Team Initials               Coach Name Line-up  \
# 0          201       1096           FRA      CAUDRON Raoul (FRA)       S
# 1          201       1096           MEX         LUQUE Juan (MEX)       S
# 2          201       1096           FRA      CAUDRON Raoul (FRA)       S
# 3          201       1096           MEX         LUQUE Juan (MEX)       S
# 4          201       1096           FRA      CAUDRON Raoul (FRA)       S
# ...        ...        ...           ...                      ...     ...
# 37779   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37780   255959  300186501           GER       LOEW Joachim (GER)       N
# 37781   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37782   255959  300186501           GER       LOEW Joachim (GER)       N
# 37783   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
#
#        Shirt Number       Player Name Position       Event
# ...

# %%
# Lectura de tablas de la web
# Pokedex: https://pokemondb.net/pokedex/all
# pip install lxml
import requests

# %%
url = "https://pokemondb.net/pokedex/all"
html_text = requests.get(url).content

# %%
contenido = pandas.read_html(html_text)

# %%
type(contenido)
# Out:
# list

# %%
len(contenido)
# Out:
# 1

# %%
df_pekedex = contenido[0]
df_pekedex
# Out:
#          #                      Name            Type  Total   HP  Attack  \
# 0        1                 Bulbasaur   Grass  Poison    318   45      49
# 1        2                   Ivysaur   Grass  Poison    405   60      62
# 2        3                  Venusaur   Grass  Poison    525   80      82
# 3        3   Venusaur  Mega Venusaur   Grass  Poison    625   80     100
# 4        4                Charmander            Fire    309   39      52
# ...    ...                       ...             ...    ...  ...     ...
# 1210  1023                Iron Crown  Steel  Psychic    590   90      72
# 1211  1024    Terapagos  Normal Form          Normal    450   90      65
# 1212  1024  Terapagos  Terastal Form          Normal    600   95      95
# 1213  1024   Terapagos  Stellar Form          Normal    700  160     105
# 1214  1025                 Pecharunt   Poison  Ghost    600   88      88
#
#       Defense  Sp. Atk  Sp. Def  Speed
# 0          49       65       65     45
# ...

# %%
# Exportar resultados
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  attack  defense  sp_attack  sp_defense  \
# 0               1   Bulbasaur  45      49       49         65          65
# 1               2     Ivysaur  60      62       63         80          80
# 2               3    Venusaur  80     100      123        122         120
# 3               4  Charmander  39      52       43         60          50
# 4               5  Charmeleon  58      64       58         80          65
#
#    speed  type1   type2  height_m  weight_kg  generation  is_legendary
# 0     45  grass  poison       0.7        6.9           1             0
# 1     60  grass  poison       1.0       13.0           1             0
# 2     80  grass  poison       2.0      100.0           1             0
# 3     65   fire     NaN       0.6        8.5           1             0
# 4     80   fire     NaN       1.1       19.0           1             0

# %%
df_pokedex.to_csv('C:\\Users\\ivanh\\Downloads\\files\\pokedex_web.xlsx')

# %%
# Exploración
df_pokedex = pandas.read_csv(
    'C:\\Users\\ivanh\\Downloads\\files\\pokedex.csv')
df_pokedex.head(10)
# Out:
#    pokedex_number        name  hp  attack  defense  sp_attack  sp_defense  \
# 0               1   Bulbasaur  45      49       49         65          65
# 1               2     Ivysaur  60      62       63         80          80
# 2               3    Venusaur  80     100      123        122         120
# 3               4  Charmander  39      52       43         60          50
# 4               5  Charmeleon  58      64       58         80          65
# 5               6   Charizard  78     104       78        159         115
# 6               7    Squirtle  44      48       65         50          64
# 7               8   Wartortle  59      63       80         65          80
# 8               9   Blastoise  79     103      120        135         115
# 9              10    Caterpie  45      30       35         20          20
#
#    speed  type1   type2  height_m  weight_kg  generation  is_legendary
# 0     45  grass  poison       0.7        6.9           1             0
# ...

# %%
df_pokedex.shape
# Out:
# (801, 14)

# %%
df_pokedex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pokedex_number  801 non-null    int64
#  1   name            801 non-null    object
#  2   hp              801 non-null    int64
#  3   attack          801 non-null    int64
#  4   defense         801 non-null    int64
#  5   sp_attack       801 non-null    int64
#  6   sp_defense      801 non-null    int64
#  7   speed           801 non-null    int64
#  8   type1           801 non-null    object
#  9   type2           417 non-null    object
#  10  height_m        781 non-null    float64
#  11  weight_kg       781 non-null    float64
#  12  generation      801 non-null    int64
#  13  is_legendary    801 non-null    int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 87.7+ KB

# %%
df_pokedex.describe()
# Out:
#        pokedex_number          hp      attack     defense   sp_attack  \
# count      801.000000  801.000000  801.000000  801.000000  801.000000
# mean       401.000000   68.958801   77.857678   73.008739   71.305868
# std        231.373075   26.576015   32.158820   30.769159   32.353826
# min          1.000000    1.000000    5.000000    5.000000   10.000000
# 25%        201.000000   50.000000   55.000000   50.000000   45.000000
# 50%        401.000000   65.000000   75.000000   70.000000   65.000000
# 75%        601.000000   80.000000  100.000000   90.000000   91.000000
# max        801.000000  255.000000  185.000000  230.000000  194.000000
#
#        sp_defense       speed    height_m   weight_kg  generation  \
# count  801.000000  801.000000  781.000000  781.000000  801.000000
# mean    70.911361   66.334582    1.163892   61.378105    3.690387
# std     27.942501   28.907662    1.080326  109.354766    1.930420
# min     20.000000    5.000000    0.100000    0.100000    1.000000
# ...

# %%
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  attack  defense  sp_attack  sp_defense  \
# 0               1   Bulbasaur  45      49       49         65          65
# 1               2     Ivysaur  60      62       63         80          80
# 2               3    Venusaur  80     100      123        122         120
# 3               4  Charmander  39      52       43         60          50
# 4               5  Charmeleon  58      64       58         80          65
#
#    speed  type1   type2  height_m  weight_kg  generation  is_legendary
# 0     45  grass  poison       0.7        6.9           1             0
# 1     60  grass  poison       1.0       13.0           1             0
# 2     80  grass  poison       2.0      100.0           1             0
# 3     65   fire     NaN       0.6        8.5           1             0
# 4     80   fire     NaN       1.1       19.0           1             0

# %%
df_pokedex['total_attack'] = df_pokedex['attack'] + df_pokedex['sp_attack']
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  attack  defense  sp_attack  sp_defense  \
# 0               1   Bulbasaur  45      49       49         65          65
# 1               2     Ivysaur  60      62       63         80          80
# 2               3    Venusaur  80     100      123        122         120
# 3               4  Charmander  39      52       43         60          50
# 4               5  Charmeleon  58      64       58         80          65
#
#    speed  type1   type2  height_m  weight_kg  generation  is_legendary  \
# 0     45  grass  poison       0.7        6.9           1             0
# 1     60  grass  poison       1.0       13.0           1             0
# 2     80  grass  poison       2.0      100.0           1             0
# 3     65   fire     NaN       0.6        8.5           1             0
# 4     80   fire     NaN       1.1       19.0           1             0
#
#    total_attack
# 0           114
# 1           142
# 2           222
# 3           112
# ...

# %%
df_pokedex.get(['hp', 'attack', 'defense',	'sp_attack', 'sp_defense', 'speed']).sum(axis = 1)
# Out:
# 0      318
# 1      405
# 2      625
# 3      309
# 4      405
#       ...
# 796    570
# 797    570
# 798    570
# 799    600
# 800    600
# Length: 801, dtype: int64

# %%
df_pokedex['total_stats'] = df_pokedex.get(['hp', 'attack', 'defense',	'sp_attack', 'sp_defense', 'speed']).sum(axis = 1)
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  attack  defense  sp_attack  sp_defense  \
# 0               1   Bulbasaur  45      49       49         65          65
# 1               2     Ivysaur  60      62       63         80          80
# 2               3    Venusaur  80     100      123        122         120
# 3               4  Charmander  39      52       43         60          50
# 4               5  Charmeleon  58      64       58         80          65
#
#    speed  type1   type2  height_m  weight_kg  generation  is_legendary  \
# 0     45  grass  poison       0.7        6.9           1             0
# 1     60  grass  poison       1.0       13.0           1             0
# 2     80  grass  poison       2.0      100.0           1             0
# 3     65   fire     NaN       0.6        8.5           1             0
# 4     80   fire     NaN       1.1       19.0           1             0
#
#    total_attack  total_stats
# 0           114          318
# 1           142          405
# ...

# %%
# apply
df_pokedex['generation'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7], dtype=int64)

# %%
def generaciones(numero):
    if numero == 1:
        return 'Kanto'
    elif numero == 2:
        return 'Johto'
    elif numero == 3:
        return 'Hoenn'
    elif numero == 4:
        return 'Sinnoh'
    elif numero == 5:
        return 'Unova'
    elif numero == 6:
        return 'Kalos'
    elif numero == 7:
        return 'Alola'
df_pokedex['region'] = df_pokedex['generation'].apply(generaciones)
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  attack  defense  sp_attack  sp_defense  \
# 0               1   Bulbasaur  45      49       49         65          65
# 1               2     Ivysaur  60      62       63         80          80
# 2               3    Venusaur  80     100      123        122         120
# 3               4  Charmander  39      52       43         60          50
# 4               5  Charmeleon  58      64       58         80          65
#
#    speed  type1   type2  height_m  weight_kg  generation  is_legendary  \
# 0     45  grass  poison       0.7        6.9           1             0
# 1     60  grass  poison       1.0       13.0           1             0
# 2     80  grass  poison       2.0      100.0           1             0
# 3     65   fire     NaN       0.6        8.5           1             0
# 4     80   fire     NaN       1.1       19.0           1             0
#
#    total_attack  total_stats region
# 0           114          318  Kanto
# ...

# %%
df_pokedex.tail()
# Out:
#      pokedex_number        name   hp  attack  defense  sp_attack  sp_defense  \
# 796             797  Celesteela   97     101      103        107         101
# 797             798     Kartana   59     181      131         59          31
# 798             799    Guzzlord  223     101       53         97          53
# 799             800    Necrozma   97     107      101        127          89
# 800             801    Magearna   80      95      115        130         115
#
#      speed    type1   type2  height_m  weight_kg  generation  is_legendary  \
# 796     61    steel  flying       9.2      999.9           7             1
# 797    109    grass   steel       0.3        0.1           7             1
# 798     43     dark  dragon       5.5      888.0           7             1
# 799     79  psychic     NaN       2.4      230.0           7             1
# 800     65    steel   fairy       1.0       80.5           7             1
#
#      total_attack  total_stats region
# ...

# %%
# filtros
df_pokedex['is_legendary'] == 1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 796     True
# 797     True
# 798     True
# 799     True
# 800     True
# Name: is_legendary, Length: 801, dtype: bool

# %%
df_pokedex.loc[df_pokedex['is_legendary'] == 1]
# Out:
#      pokedex_number        name   hp  attack  defense  sp_attack  sp_defense  \
# 143             144    Articuno   90      85      100         95         125
# 144             145      Zapdos   90      90       85        125          90
# 145             146     Moltres   90     100       90        125          85
# 149             150      Mewtwo  106     150       70        194         120
# 150             151         Mew  100     100      100        100         100
# ..              ...         ...  ...     ...      ...        ...         ...
# 796             797  Celesteela   97     101      103        107         101
# 797             798     Kartana   59     181      131         59          31
# 798             799    Guzzlord  223     101       53         97          53
# 799             800    Necrozma   97     107      101        127          89
# 800             801    Magearna   80      95      115        130         115
#
# ...

# %%
import numpy
df_pokedex.loc[numpy.logical_and(df_pokedex['is_legendary'] == 1, df_pokedex['region'] == 'Johto')]
# Out:
#      pokedex_number     name   hp  attack  defense  sp_attack  sp_defense  \
# 242             243   Raikou   90      85       75        115         100
# 243             244    Entei  115     115       85         90          75
# 244             245  Suicune  100      75      115         90         115
# 248             249    Lugia  106      90      130         90         154
# 249             250    Ho-Oh  106     130       90        110         154
# 250             251   Celebi  100     100      100        100         100
#
#      speed     type1   type2  height_m  weight_kg  generation  is_legendary  \
# 242    115  electric     NaN       1.9      178.0           2             1
# 243    100      fire     NaN       2.1      198.0           2             1
# 244     85     water     NaN       2.0      187.0           2             1
# 248    110   psychic  flying       5.2      216.0           2             1
# ...

# %%
# sort
df_kanto = df_pokedex.loc[df_pokedex['region'] == 'Kanto']
df_kanto.head()
# Out:
#    pokedex_number        name  hp  attack  defense  sp_attack  sp_defense  \
# 0               1   Bulbasaur  45      49       49         65          65
# 1               2     Ivysaur  60      62       63         80          80
# 2               3    Venusaur  80     100      123        122         120
# 3               4  Charmander  39      52       43         60          50
# 4               5  Charmeleon  58      64       58         80          65
#
#    speed  type1   type2  height_m  weight_kg  generation  is_legendary  \
# 0     45  grass  poison       0.7        6.9           1             0
# 1     60  grass  poison       1.0       13.0           1             0
# 2     80  grass  poison       2.0      100.0           1             0
# 3     65   fire     NaN       0.6        8.5           1             0
# 4     80   fire     NaN       1.1       19.0           1             0
#
#    total_attack  total_stats region
# 0           114          318  Kanto
# ...

# %%
df_kanto.sort_values(by = 'total_stats')
# Out:
#      pokedex_number       name   hp  attack  defense  sp_attack  sp_defense  \
# 12               13     Weedle   40      35       30         20          20
# 9                10   Caterpie   45      30       35         20          20
# 128             129   Magikarp   20      10       55         15          20
# 13               14     Kakuna   45      25       50         25          25
# 10               11    Metapod   50      20       55         25          25
# ..              ...        ...  ...     ...      ...        ...         ...
# 2                 3   Venusaur   80     100      123        122         120
# 8                 9  Blastoise   79     103      120        135         115
# 5                 6  Charizard   78     104       78        159         115
# 129             130   Gyarados   95     155      109         70         130
# 149             150     Mewtwo  106     150       70        194         120
#
# ...

# %%
df_kanto.sort_values(by = 'total_stats', ascending = False)
# Out:
#      pokedex_number       name   hp  attack  defense  sp_attack  sp_defense  \
# 149             150     Mewtwo  106     150       70        194         120
# 129             130   Gyarados   95     155      109         70         130
# 5                 6  Charizard   78     104       78        159         115
# 8                 9  Blastoise   79     103      120        135         115
# 2                 3   Venusaur   80     100      123        122         120
# ..              ...        ...  ...     ...      ...        ...         ...
# 10               11    Metapod   50      20       55         25          25
# 13               14     Kakuna   45      25       50         25          25
# 128             129   Magikarp   20      10       55         15          20
# 9                10   Caterpie   45      30       35         20          20
# 12               13     Weedle   40      35       30         20          20
#
# ...

# %%
# groupby
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  attack  defense  sp_attack  sp_defense  \
# 0               1   Bulbasaur  45      49       49         65          65
# 1               2     Ivysaur  60      62       63         80          80
# 2               3    Venusaur  80     100      123        122         120
# 3               4  Charmander  39      52       43         60          50
# 4               5  Charmeleon  58      64       58         80          65
#
#    speed  type1   type2  height_m  weight_kg  generation  is_legendary  \
# 0     45  grass  poison       0.7        6.9           1             0
# 1     60  grass  poison       1.0       13.0           1             0
# 2     80  grass  poison       2.0      100.0           1             0
# 3     65   fire     NaN       0.6        8.5           1             0
# 4     80   fire     NaN       1.1       19.0           1             0
#
#    total_attack  total_stats region
# 0           114          318  Kanto
# ...

# %%
df_pokedex_group = df_pokedex.get(['region', 'name'])
df_pokedex_group.head()
df_pokedex_group.tail()
# Out:
#     region        name
# 796  Alola  Celesteela
# 797  Alola     Kartana
# 798  Alola    Guzzlord
# 799  Alola    Necrozma
# 800  Alola    Magearna

# %%
df_pokedex_group.groupby('region').count()
# Out:
#         name
# region
# Alola     80
# Hoenn    135
# Johto    100
# Kalos     72
# Kanto    151
# Sinnoh   107
# Unova    156

# %%
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  attack  defense  sp_attack  sp_defense  \
# 0               1   Bulbasaur  45      49       49         65          65
# 1               2     Ivysaur  60      62       63         80          80
# 2               3    Venusaur  80     100      123        122         120
# 3               4  Charmander  39      52       43         60          50
# 4               5  Charmeleon  58      64       58         80          65
#
#    speed  type1   type2  height_m  weight_kg  generation  is_legendary  \
# 0     45  grass  poison       0.7        6.9           1             0
# 1     60  grass  poison       1.0       13.0           1             0
# 2     80  grass  poison       2.0      100.0           1             0
# 3     65   fire     NaN       0.6        8.5           1             0
# 4     80   fire     NaN       1.1       19.0           1             0
#
#    total_attack  total_stats region
# 0           114          318  Kanto
# ...

# %%
df_numeric = df_pokedex.select_dtypes(include=['float64', 'int64'])

df_pokedex.groupby('region').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\groupby.py:1870, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1869 try:
# -> 1870     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1871 except Exception as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ...

# %%
df_pokedex.get(['is_legendary', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed'])\
    .groupby('is_legendary').mean()
# Out:
#                      hp      attack    defense   sp_attack  sp_defense  \
# is_legendary
# 0             66.424077   74.841313  70.481532   67.240766   67.945280
# 1             95.428571  109.357143  99.400000  113.757143  101.885714
#
#                   speed
# is_legendary
# 0             63.548564
# 1             95.428571

# %%
# gráficos
df_pokedex.head()
# Out:
#    pokedex_number        name  hp  attack  defense  sp_attack  sp_defense  \
# 0               1   Bulbasaur  45      49       49         65          65
# 1               2     Ivysaur  60      62       63         80          80
# 2               3    Venusaur  80     100      123        122         120
# 3               4  Charmander  39      52       43         60          50
# 4               5  Charmeleon  58      64       58         80          65
#
#    speed  type1   type2  height_m  weight_kg  generation  is_legendary  \
# 0     45  grass  poison       0.7        6.9           1             0
# 1     60  grass  poison       1.0       13.0           1             0
# 2     80  grass  poison       2.0      100.0           1             0
# 3     65   fire     NaN       0.6        8.5           1             0
# 4     80   fire     NaN       1.1       19.0           1             0
#
#    total_attack  total_stats region
# 0           114          318  Kanto
# ...

# %%
df_pokedex.get(['hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed'])\
          .plot(kind='box')
# Out:
# <Axes: >

# %%
df_pokedex.loc[numpy.logical_or(df_pokedex['type1'] == 'grass', df_pokedex['type2'] == 'grass')]\
          .get(['hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed'])\
          .plot(kind='box')
# Out:
# <Axes: >

# %%
df_pokedex.loc[numpy.logical_or(df_pokedex['type1'] == 'fighting', df_pokedex['type2'] == 'fighting')]\
          .get(['hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed'])\
          .plot(kind='box')
# Out:
# <Axes: >

# %%
df_pokedex.loc[numpy.logical_or(df_pokedex['type1'] == 'fire', df_pokedex['type2'] == 'fire')]\
          .get(['hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed'])\
          .plot(kind='box')
# Out:
# <Axes: >

# %%
df_pokedex['attack'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
