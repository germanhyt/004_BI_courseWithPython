# %%
# Fuente: https://github.com/datahackformation/notebooks-y-datasets/tree/master/notebooks

import numpy
import pandas
import os

# %%
# path_archivos = pandas.read_csv(
#     'C:\\Users\\ivanh\\Downloads\\files')
# os.listdir(path_archivos)

# Lectura de archivos
df_mundiales = pandas.read_excel(
    'C:\\Users\\ivanh\\Downloads\\files\\world_cups.xlsx', sheet_name='world_cups')

df_matches = pandas.read_excel(
    'C:\\Users\\ivanh\\Downloads\\files\\world_cups.xlsx', sheet_name='matches')

df_players = pandas.read_excel(
    'C:\\Users\\ivanh\\Downloads\\files\\world_cups.xlsx', sheet_name='players')

# %%
df_mundiales.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17        363
# 2           84              15             18      375.7
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607

# %%
df_matches.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# ...

# %%
df_players.head()
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
# ¿De cuántos mundianles tenemos información?
df_mundiales.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17        363
# 2           84              15             18      375.7
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607

# %%
df_mundiales.shape
# Out:
# (20, 10)

# %%
len(df_mundiales)
# Out:
# 20

# %%
# Obtener el nombre completo de cada mundial
# Uruguay 1930
# Brasil 2014

df_mundiales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            20 non-null     int64
#  1   Country         20 non-null     object
#  2   Winner          20 non-null     object
#  3   Runners-Up      20 non-null     object
#  4   Third           20 non-null     object
#  5   Fourth          20 non-null     object
#  6   GoalsScored     20 non-null     int64
#  7   QualifiedTeams  20 non-null     int64
#  8   MatchesPlayed   20 non-null     int64
#  9   Attendance      20 non-null     object
# dtypes: int64(4), object(6)
# memory usage: 1.7+ KB

# %%
df_mundiales['Year'] = df_mundiales['Year'].astype(str)
df_mundiales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            20 non-null     object
#  1   Country         20 non-null     object
#  2   Winner          20 non-null     object
#  3   Runners-Up      20 non-null     object
#  4   Third           20 non-null     object
#  5   Fourth          20 non-null     object
#  6   GoalsScored     20 non-null     int64
#  7   QualifiedTeams  20 non-null     int64
#  8   MatchesPlayed   20 non-null     int64
#  9   Attendance      20 non-null     object
# dtypes: int64(3), object(7)
# memory usage: 1.7+ KB

# %%
df_mundiales['Name'] = df_mundiales['Country'] + " " + df_mundiales['Year']
df_mundiales.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance              Name
# 0           70              13             18    590.549      Uruguay 1930
# 1           70              16             17        363        Italy 1934
# 2           84              15             18      375.7       France 1938
# 3           88              13             22  1.045.246       Brazil 1950
# 4          140              16             26    768.607  Switzerland 1954

# %%
columnas = list(df_mundiales.columns)
columnas
# Out:
# ['Year',
#  'Country',
#  'Winner',
#  'Runners-Up',
#  'Third',
#  'Fourth',
#  'GoalsScored',
#  'QualifiedTeams',
#  'MatchesPlayed',
#  'Attendance',
#  'Name']

# %%
# toma todos los elementos de la lista columnas excepto el último. El operador : se utiliza para el slicing de listas en Python, y -1 se refiere al último elemento de la lista.
columnas = ['Name'] + columnas[:-1]
columnas
# Out:
# ['Name',
#  'Year',
#  'Country',
#  'Winner',
#  'Runners-Up',
#  'Third',
#  'Fourth',
#  'GoalsScored',
#  'QualifiedTeams',
#  'MatchesPlayed',
#  'Attendance']

# %%
df_mundiales = df_mundiales.get(columnas)
df_mundiales.head()
# Out:
#                Name  Year      Country      Winner      Runners-Up    Third  \
# 0      Uruguay 1930  1930      Uruguay     Uruguay       Argentina      USA
# 1        Italy 1934  1934        Italy       Italy  Czechoslovakia  Germany
# 2       France 1938  1938       France       Italy         Hungary   Brazil
# 3       Brazil 1950  1950       Brazil     Uruguay          Brazil   Sweden
# 4  Switzerland 1954  1954  Switzerland  Germany FR         Hungary  Austria
#
#        Fourth  GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0  Yugoslavia           70              13             18    590.549
# 1     Austria           70              16             17        363
# 2      Sweden           84              15             18      375.7
# 3       Spain           88              13             22  1.045.246
# 4     Uruguay          140              16             26    768.607

# %%
# Países que campeonaron de locales

# df_locales = df_mundiales.loc[df_mundiales['Country']
#   == df_mundiales['Winner']]
df_locales = df_mundiales.loc[df_mundiales['Country']
                              == df_mundiales['Winner'], ['Name', 'Winner']]
df_locales
# Out:
#               Name  Year    Country     Winner      Runners-Up     Third  \
# 0     Uruguay 1930  1930    Uruguay    Uruguay       Argentina       USA
# 1       Italy 1934  1934      Italy      Italy  Czechoslovakia   Germany
# 7     England 1966  1966    England    England      Germany FR  Portugal
# 10  Argentina 1978  1978  Argentina  Argentina     Netherlands    Brazil
# 15     France 1998  1998     France     France          Brazil   Croatia
#
#           Fourth  GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0     Yugoslavia           70              13             18    590.549
# 1        Austria           70              16             17        363
# 7   Soviet Union           89              16             32  1.563.135
# 10         Italy          102              16             38  1.545.791
# 15   Netherlands          171              32             64  2.785.100

# %%
df_locales_2 = df_mundiales.query('Country==Winner')
df_locales_2
# Out:
#               Name  Year    Country     Winner      Runners-Up     Third  \
# 0     Uruguay 1930  1930    Uruguay    Uruguay       Argentina       USA
# 1       Italy 1934  1934      Italy      Italy  Czechoslovakia   Germany
# 7     England 1966  1966    England    England      Germany FR  Portugal
# 10  Argentina 1978  1978  Argentina  Argentina     Netherlands    Brazil
# 15     France 1998  1998     France     France          Brazil   Croatia
#
#           Fourth  GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0     Yugoslavia           70              13             18    590.549
# 1        Austria           70              16             17        363
# 7   Soviet Union           89              16             32  1.563.135
# 10         Italy          102              16             38  1.545.791
# 15   Netherlands          171              32             64  2.785.100

# %%
# Partidos de mundial con más goles
df_matches.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# ...

# %%
df_matches_relevant = df_matches.get(
    ['Year', 'Home Team Name', 'Away Team Name', 'Home Team Goals', 'Away Team Goals'])
df_matches_relevant.head()
# Out:
#    Year Home Team Name Away Team Name  Home Team Goals  Away Team Goals
# 0  1930         France         Mexico                4                1
# 1  1930            USA        Belgium                3                0
# 2  1930     Yugoslavia         Brazil                2                1
# 3  1930        Romania           Peru                3                1
# 4  1930      Argentina         France                1                0

# %%
df_matches_relevant['Total Goals'] = df_matches_relevant['Home Team Goals'] + \
    df_matches_relevant['Away Team Goals']
df_matches_relevant.head()
# Out:
# C:\Users\ivanh\AppData\Local\Temp\ipykernel_31248\2408316722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_matches_relevant['Total Goals'] = df_matches_relevant['Home Team Goals'] + df_matches_relevant['Away Team Goals']
#    Year Home Team Name Away Team Name  Home Team Goals  Away Team Goals  \
# 0  1930         France         Mexico                4                1
# 1  1930            USA        Belgium                3                0
# 2  1930     Yugoslavia         Brazil                2                1
# 3  1930        Romania           Peru                3                1
# 4  1930      Argentina         France                1                0
#
#    Total Goals
# 0            5
# 1            3
# ...

# %%
df_matches_relevant.sort_values(by='Total Goals', ascending=False).head(20)
# Out:
#      Year Home Team Name  Away Team Name  Home Team Goals  Away Team Goals  \
# 94   1954        Austria     Switzerland                7                5
# 312  1982        Hungary     El Salvador               10                1
# 87   1954        Hungary      Germany FR                8                3
# 40   1938         Brazil          Poland                6                5
# 105  1958         France        Paraguay                7                3
# 10   1930      Argentina          Mexico                6                3
# 91   1954     Germany FR          Turkey                7                2
# 243  1974     Yugoslavia           Zaire                9                0
# 80   1954        Hungary  Korea Republic                9                0
# 134  1958         France      Germany FR                6                3
# 70   1950         Brazil          Sweden                7                1
# ...

# %%
df_matches_relevant.sort_values(by='Total Goals', ascending=False)\
    .loc[df_matches_relevant['Year'] > 2000]\
    .head(20)
# Out:
#      Year   Home Team Name             Away Team Name  Home Team Goals  \
# 848  2014           Brazil                    Germany                1
# 826  2014           Brazil                    Germany                1
# 583  2002          Germany               Saudi Arabia                8
# 737  2010         Portugal                  Korea DPR                7
# 796  2014      Switzerland                     France                2
# 620  2002       Costa Rica                     Brazil                2
# 774  2014            Spain                Netherlands                1
# 802  2014   Korea Republic                    Algeria                2
# 613  2002          Senegal                    Uruguay                3
# 644  2006          Germany                 Costa Rica                4
# 664  2006        Argentina  rn">Serbia and Montenegro                6
# 806  2014         Cameroon                     Brazil                1
# ...

# %%
# Goles promedio por partido para cada mundial
df_mundiales.head()
# Out:
#                Name  Year      Country      Winner      Runners-Up    Third  \
# 0      Uruguay 1930  1930      Uruguay     Uruguay       Argentina      USA
# 1        Italy 1934  1934        Italy       Italy  Czechoslovakia  Germany
# 2       France 1938  1938       France       Italy         Hungary   Brazil
# 3       Brazil 1950  1950       Brazil     Uruguay          Brazil   Sweden
# 4  Switzerland 1954  1954  Switzerland  Germany FR         Hungary  Austria
#
#        Fourth  GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0  Yugoslavia           70              13             18    590.549
# 1     Austria           70              16             17        363
# 2      Sweden           84              15             18      375.7
# 3       Spain           88              13             22  1.045.246
# 4     Uruguay          140              16             26    768.607

# %%
df_mundiales['AvgGoals'] = df_mundiales['GoalsScored'] / \
    df_mundiales['MatchesPlayed']
df_mundiales.head()
# Out:
#                Name  Year      Country      Winner      Runners-Up    Third  \
# 0      Uruguay 1930  1930      Uruguay     Uruguay       Argentina      USA
# 1        Italy 1934  1934        Italy       Italy  Czechoslovakia  Germany
# 2       France 1938  1938       France       Italy         Hungary   Brazil
# 3       Brazil 1950  1950       Brazil     Uruguay          Brazil   Sweden
# 4  Switzerland 1954  1954  Switzerland  Germany FR         Hungary  Austria
#
#        Fourth  GoalsScored  QualifiedTeams  MatchesPlayed Attendance  AvgGoals
# 0  Yugoslavia           70              13             18    590.549  3.888889
# 1     Austria           70              16             17        363  4.117647
# 2      Sweden           84              15             18      375.7  4.666667
# 3       Spain           88              13             22  1.045.246  4.000000
# 4     Uruguay          140              16             26    768.607  5.384615

# %%
# Goleadores históricos de los mundiales
df_players.head()
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
df_players_events = df_players.dropna(subset=['Event'])
df_players_events.head()
# Out:
#     RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 2       201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3       201     1096           MEX     LUQUE Juan (MEX)       S             0
# 6       201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 14      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 35      201     1090           USA     MILLAR Bob (USA)       S             0
#
#          Player Name Position      Event
# 2   Marcel LANGILLER      NaN       G40'
# 3       Juan CARRENO      NaN       G70'
# 6    Andre MASCHINOT      NaN  G43' G87'
# 14    Lucien LAURENT      NaN       G19'
# 35        Tom FLORIE        C       G45'

# %%
df_players_events.head(100)
# Out:
#       RoundID  MatchID Team Initials            Coach Name Line-up  \
# 2         201     1096           FRA   CAUDRON Raoul (FRA)       S
# 3         201     1096           MEX      LUQUE Juan (MEX)       S
# 6         201     1096           FRA   CAUDRON Raoul (FRA)       S
# 14        201     1096           FRA   CAUDRON Raoul (FRA)       S
# 35        201     1090           USA      MILLAR Bob (USA)       S
# ...       ...      ...           ...                   ...     ...
# 1140      418     1106           HUN      NADAS Odon (HUN)       S
# 1143      418     1106           AUT      MEISL Hugo (AUT)       S
# 1146      418     1106           HUN      NADAS Odon (HUN)       S
# 1153      418     1106           AUT      MEISL Hugo (AUT)       S
# 1185      418     1123           ITA  POZZO Vittorio (ITA)       S
#
#       Shirt Number       Player Name Position      Event
# 2                0  Marcel LANGILLER      NaN       G40'
# ...

# %%
def cantidad_goles(cadena):
    return cadena.count('G')


cantidad_goles("G43' G87'")
# Out:
# 2

# %%
df_players_events['Goals'] = df_players_events['Event'].apply(cantidad_goles)

df_players_events.head()
# Out:
# C:\Users\ivanh\AppData\Local\Temp\ipykernel_31248\1460547394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_players_events['Goals'] = df_players_events['Event'].apply(cantidad_goles)
#     RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 2       201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3       201     1096           MEX     LUQUE Juan (MEX)       S             0
# 6       201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 14      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 35      201     1090           USA     MILLAR Bob (USA)       S             0
#
#          Player Name Position      Event  Goals
# ...

# %%
df_players_events.get(['Player Name', 'Goals'])\
    .groupby('Player Name')\
    .sum()\
    .sort_values(by='Goals', ascending=False)\
    .head(10)
# Out:
#                                       Goals
# Player Name
# KLOSE                                    17
# RONALDO                                  16
# Just FONTAINE                            13
# Gerd MUELLER                             13
# PELÔøΩ (Edson Arantes do Nascimento)     12
# Sandor KOCSIS                            11
# MÔøΩLLER                                 11
# Grzegorz LATO                            10
# Helmut RAHN                              10
# Karl-Heinz RUMMENIGGE                     9

# %%
# Gráfico de barras con la cantidad de goles por Mundial

df_mundiales.head()

df_mundiales.plot(kind='bar', x='Year', y='GoalsScored')
# Out:
# <Axes: xlabel='Year'>

# %%
df_mundiales.plot(kind='barh', x='Year', y='GoalsScored')
# Out:
# <Axes: ylabel='Year'>
